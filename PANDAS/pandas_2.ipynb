# %%
# !pip install pandas

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

# %%
df = pd.read_csv(url)

# %%
df # DataFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Slicing

# %%
df.iloc[0:3, 0:4] # start : end -> end is exclusive
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina

# %%
df.iloc[[0, 2], [0, 2, 3]]
# Out:
#    PassengerId  Pclass                     Name
# 0            1       3  Braund, Mr. Owen Harris
# 2            3       3   Heikkinen, Miss. Laina

# %%
df.loc[0:3, ["PassengerId", "Survived", "Pclass", "Name"]] # start : end -> end is inclusive
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)

# %%
df.loc[[0, 2], ["PassengerId", "Pclass", "Name"]]
# Out:
#    PassengerId  Pclass                     Name
# 0            1       3  Braund, Mr. Owen Harris
# 2            3       3   Heikkinen, Miss. Laina

# %%
df.loc[0, ["PassengerId", "Pclass", "Name"]]
# Out:
# PassengerId                          1
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Name: 0, dtype: object

# %% [markdown]
# head and tail

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# ...

# %% [markdown]
# Conditional Slicing

# %%
# condition -> Survived = 1, Sex = male, Age > 20 = (df["Survived"] == 1) & (df["Sex"] == "male") & (df["Age"] > 20)
# df[condition]

df[(df["Survived"] == 1) & (df["Sex"] == "male") & (df["Age"] > 20)].head()
# Out:
#     PassengerId  Survived  Pclass                             Name   Sex  \
# 21           22         1       2            Beesley, Mr. Lawrence  male
# 23           24         1       1     Sloper, Mr. William Thompson  male
# 74           75         1       3                    Bing, Mr. Lee  male
# 81           82         1       3      Sheerlinck, Mr. Jan Baptist  male
# 97           98         1       1  Greenfield, Mr. William Bertram  male
#
#      Age  SibSp  Parch    Ticket     Fare    Cabin Embarked
# 21  34.0      0      0    248698  13.0000      D56        S
# 23  28.0      0      0    113788  35.5000       A6        S
# 74  32.0      0      0      1601  56.4958      NaN        S
# 81  29.0      0      0    345779   9.5000      NaN        S
# 97  23.0      0      1  PC 17759  63.3583  D10 D12        C

# %%
df[(df["Survived"] == 1) & (df["Sex"] == "male") & (df["Age"] > 20)][["Survived", "Pclass", "Name", "Fare"]]
# Out:
#      Survived  Pclass                             Name     Fare
# 21          1       2            Beesley, Mr. Lawrence  13.0000
# 23          1       1     Sloper, Mr. William Thompson  35.5000
# 74          1       3                    Bing, Mr. Lee  56.4958
# 81          1       3      Sheerlinck, Mr. Jan Baptist   9.5000
# 97          1       1  Greenfield, Mr. William Bertram  63.3583
# ..        ...     ...                              ...      ...
# 804         1       3          Hedman, Mr. Oskar Arvid   6.9750
# 821         1       3                Lulic, Mr. Nikola   8.6625
# 838         1       3                  Chip, Mr. Chang  56.4958
# 857         1       1           Daly, Mr. Peter Denis   26.5500
# 889         1       1            Behr, Mr. Karl Howell  30.0000
#
# [64 rows x 4 columns]

# %%
len(df)
# Out:
# 891

# %%
len(df[df["Survived"] == 1])
# Out:
# 342

# %%
male_df = df[df["Sex"] == "male"] # might create a view

male_df["Age"] += 1
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19156\1030931098.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_df["Age"] += 1

# %%
male_df.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  23.0
# 4            5         0       3        Allen, Mr. William Henry  male  36.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  55.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   3.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
male_df = df[df["Sex"] == "male"].copy()

male_df["Age"] += 1

# %%
male_df.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  23.0
# 4            5         0       3        Allen, Mr. William Henry  male  36.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  55.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   3.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# iloc -> copy
# loc, df[] -> might be view -> .copy()

# %% [markdown]
# Set Index

# %%
df_set_index = df.set_index("PassengerId")

df_set_index.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_set_index = df_set_index.reset_index()

df_set_index.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_set_index = df.set_index("PassengerId")

df_set_index.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_set_index.reset_index(inplace=True)

df_set_index.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ### Reindex

# %% [markdown]
# For Row:

# %%
sales_jan = pd.DataFrame({
    'Sales': [250, 400, 300]
}, index=['Store_A', 'Store_B', 'Store_C'])

sales_jan
# Out:
#          Sales
# Store_A    250
# Store_B    400
# Store_C    300

# %%
sales_feb = pd.DataFrame({
    'Sales': [260, 310]
}, index=['Store_A', 'Store_C'])

sales_feb
# Out:
#          Sales
# Store_A    260
# Store_C    310

# %%
sales_feb - sales_jan
# Out:
#          Sales
# Store_A   10.0
# Store_B    NaN
# Store_C   10.0

# %%
sales_feb_aligned = sales_feb.reindex(sales_jan.index)

sales_feb_aligned
# Out:
#          Sales
# Store_A  260.0
# Store_B    NaN
# Store_C  310.0

# %%
sales_feb_aligned = sales_feb.reindex(sales_jan.index, fill_value=0)

sales_feb_aligned
# Out:
#          Sales
# Store_A    260
# Store_B      0
# Store_C    310

# %%
sales_feb_aligned - sales_jan
# Out:
#          Sales
# Store_A     10
# Store_B   -400
# Store_C     10

# %% [markdown]
# For Column:

# %%
source_a = pd.DataFrame({
    'Product': ['Laptop', 'Tablet', 'Phone'],
    'Price': [1000, 500, 800],
    'Stock': [30, 50, 100]
})

source_a
# Out:
#   Product  Price  Stock
# 0  Laptop   1000     30
# 1  Tablet    500     50
# 2   Phone    800    100

# %%
source_b = pd.DataFrame({
    'Price': [980, 520, 810],
    'Product': ['Laptop', 'Tablet', 'Phone']
})

source_b
# Out:
#    Price Product
# 0    980  Laptop
# 1    520  Tablet
# 2    810   Phone

# %%
source_a.columns
# Out:
# Index(['Product', 'Price', 'Stock'], dtype='object')

# %%
source_b_aligned = source_b.reindex(columns=source_a.columns, fill_value=0)

source_b_aligned
# Out:
#   Product  Price  Stock
# 0  Laptop    980      0
# 1  Tablet    520      0
# 2   Phone    810      0

# %% [markdown]
# ### Iteration in Pandas

# %%
df = pd.DataFrame({
    'Name' : ['heartine', 'gagan', 'gavin'],
    'Age' : [25, 20, 23],
    'City' : ['Delhi', 'Mumbai', 'Chennai'],
})

# %%
df
# Out:
#        Name  Age     City
# 0  heartine   25    Delhi
# 1     gagan   20   Mumbai
# 2     gavin   23  Chennai

# %%
for index, row in df.iterrows():
    print (f"{index}. {row['Name']}")
    print ("="*15)
# Out:
# 0. heartine
# ...
# 1. gagan
# ...
# 2. gavin
# ...

# %%
for row in df.itertuples():
    print (f"{row.Name}")
    print ("="*15)
# Out:
# heartine
# ...
# gagan
# ...
# gavin
# ...

# %%
for col in df.columns:
    print(f"Column: {col}")
    print (df[col].values)
    print ("="*15)
# Out:
# Column: Name
# ['heartine' 'gagan' 'gavin']
# ...
# Column: Age
# [25 20 23]
# ...
# Column: City
# ['Delhi' 'Mumbai' 'Chennai']
# ...

# %% [markdown]
# ### Condition based Columns Creation

# %%
df
# Out:
#        Name  Age     City
# 0  heartine   25    Delhi
# 1     gagan   20   Mumbai
# 2     gavin   23  Chennai

# %%
categories = []

for index, row in df.iterrows():
    if row["Age"] > 22:
        categories.append("Senior")
    else:
        categories.append("Junior")

categories
# Out:
# ['Senior', 'Junior', 'Senior']

# %%
df["Category"] = categories

# %%
df
# Out:
#        Name  Age     City Category
# 0  heartine   25    Delhi   Senior
# 1     gagan   20   Mumbai   Junior
# 2     gavin   23  Chennai   Senior

# %%
df["Maturity"] = df["Age"].apply(lambda age : "Yes" if age > 22 else "No")

# %%
df
# Out:
#        Name  Age     City Category Maturity
# 0  heartine   25    Delhi   Senior      Yes
# 1     gagan   20   Mumbai   Junior       No
# 2     gavin   23  Chennai   Senior      Yes

# %% [markdown]
# ### Sort

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

df = pd.read_csv(titanic_dataset_github_url)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sorted_df_1 = df.sort_values(by="Age")

sorted_df_1
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 644          645         1       3                    Baclini, Miss. Eugenie
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df["Age"].dtype
# Out:
# dtype('float64')

# %%
df["Age"] = df["Age"].astype("int64")
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 df["Age"] = df["Age"].astype("int64")
#
# File c:\Users\HP\miniconda3\envs\cv_collection_review_rnd\lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\HP\miniconda3\envs\cv_collection_review_rnd\lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df["Age"] = df["Age"].fillna(0).astype("int64")

# %%
df["Age"].dtype
# Out:
# dtype('int64')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
sorted_df_2 = df.sort_values(by="Age")

sorted_df_2
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 863          864         0       3     Sage, Miss. Dorothy Edith "Dolly"
# 711          712         0       1                    Klaber, Mr. Herman
# 718          719         0       3                   McEvoy, Mr. Michael
# 229          230         0       3               Lefebre, Miss. Mathilde
# 727          728         1       3              Mannion, Miss. Margareth
# ..           ...       ...     ...                                   ...
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex  Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
sorted_df_3 = df.sort_values(by=["Age", "Fare"])

sorted_df_3
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 277          278         0       2           Parkes, Mr. Francis "Frank"
# 413          414         0       2        Cunningham, Mr. Alfred Fleming
# 466          467         0       2                 Campbell, Mr. William
# 481          482         0       2      Frost, Mr. Anthony Wood "Archie"
# 633          634         0       1         Parr, Mr. William Henry Marsh
# ..           ...       ...     ...                                   ...
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex  Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
sorted_df_4 = df.sort_values(by=["Age", "Fare"], ascending=[False, True])

sorted_df_4
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 96            97         0       1
# 493          494         0       1
# 116          117         0       3
# ..           ...       ...     ...
# 334          335         1       1
# 31            32         1       1
# 305          306         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex  Age  SibSp  \
# 630               Barkworth, Mr. Algernon Henry Wilson    male   80      0
# 851                                Svensson, Mr. Johan    male   74      0
# 96                           Goldschmidt, Mr. George B    male   71      0
# 493                            Artagaveytia, Mr. Ramon    male   71      0
# 116                               Connors, Mr. Patrick    male   70      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
sorted_df_4.to_csv("Age descending and Fare Ascending in Titanic Dataset.csv")

# %%
sorted_df_5 = df.set_index("PassengerId")

sorted_df_5 = sorted_df_5.sort_index(axis=0, ascending=False)

sorted_df_5
# Out:
#              Survived  Pclass  \
# PassengerId
# 891                 0       3
# 890                 1       1
# 889                 0       3
# 888                 1       1
# 887                 0       2
# ...               ...     ...
# 5                   0       3
# 4                   1       1
# 3                   1       3
# 2                   1       1
# 1                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 891                                        Dooley, Mr. Patrick    male   32
# 890                                      Behr, Mr. Karl Howell    male   26
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female    0
# 888                               Graham, Miss. Margaret Edith  female   19
# 887                                      Montvila, Rev. Juozas    male   27
# ...                                                        ...     ...  ...
# ...

# %%
sorted_df_6 = df.sort_index(axis=1, ascending=False)

sorted_df_6
# Out:
#                Ticket  Survived  SibSp     Sex  Pclass  PassengerId  Parch  \
# 0           A/5 21171         0      1    male       3            1      0
# 1            PC 17599         1      1  female       1            2      0
# 2    STON/O2. 3101282         1      0  female       3            3      0
# 3              113803         1      1  female       1            4      0
# 4              373450         0      0    male       3            5      0
# ..                ...       ...    ...     ...     ...          ...    ...
# 886            211536         0      0    male       2          887      0
# 887            112053         1      0  female       1          888      0
# 888        W./C. 6607         0      1  female       3          889      2
# 889            111369         1      0    male       1          890      0
# 890            370376         0      0    male       3          891      0
#
# ...

# %% [markdown]
# Changing Column Orders

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

df = pd.read_csv(titanic_dataset_github_url)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
new_columns = ['Survived', 'PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df[new_columns]
# Out:
#      Survived  PassengerId  Pclass  \
# 0           0            1       3
# 1           1            2       1
# 2           1            3       3
# 3           1            4       1
# 4           0            5       3
# ..        ...          ...     ...
# 886         0          887       2
# 887         1          888       1
# 888         0          889       3
# 889         1          890       1
# 890         0          891       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sorted(df.columns)
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'Ticket']

# %%
df[sorted(df.columns)]
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888   NaN   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# ...

# %% [markdown]
# ### Working with Text Data

# %%
df["Name"].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df["Name"].str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
df["Name"].str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df["Name"].str.len()
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
df["Name"].str.replace("Mr.", "Sir", regex=False)
# Out:
# 0                                Braund, Sir Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Sir William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Sir Karl Howell
# 890                                  Dooley, Sir Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.replace(r"\(.*\)", "", regex=True)
# Out:
# 0                       Braund, Mr. Owen Harris
# 1                   Cumings, Mrs. John Bradley
# 2                        Heikkinen, Miss. Laina
# 3                 Futrelle, Mrs. Jacques Heath
# 4                      Allen, Mr. William Henry
#                          ...
# 886                       Montvila, Rev. Juozas
# 887                Graham, Miss. Margaret Edith
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 889                       Behr, Mr. Karl Howell
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df["Title"] = df["Name"].str.extract(r'(\(.*\))', expand=False)

df["Title"]
# Out:
# 0                           NaN
# 1      (Florence Briggs Thayer)
# 2                           NaN
# 3               (Lily May Peel)
# 4                           NaN
#                  ...
# 886                         NaN
# 887                         NaN
# 888                         NaN
# 889                         NaN
# 890                         NaN
# Name: Title, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df['Name'].str.extract(r'(\(.*\))', expand=True))
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Name'].str.extract(r'(\(.*\))', expand=False))
# Out:
# pandas.core.series.Series

# %%
df["Name"].str.split(",", expand=True)[0] # df["Name"][0].split(",")[0]
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: 0, Length: 891, dtype: object

# %%
df['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.lstrip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.rstrip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.find("Mr")
# Out:
# 0       8
# 1       9
# 2      -1
# 3      10
# 4       7
#        ..
# 886    -1
# 887    -1
# 888    -1
# 889     6
# 890     8
# Name: Name, Length: 891, dtype: int64

# %%
df['Name'].str.contains("Miss").sum()
# Out:
# np.int64(182)
