# %%
import pandas as pd

# %%
data = {
    'Name' : [
        'Alice', 'Bob', 'Carl', 'David'
    ],
    'Email' : [
        'alice@gmail.com', 'bob@gmail.com', 'carl@gmail.com', 'david@gmail.com'
    ]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name            Email
# 0  Alice  alice@gmail.com
# 1    Bob    bob@gmail.com
# 2   Carl   carl@gmail.com
# 3  David  david@gmail.com

# %%
df["Name"].str.pad(width=20, side="left", fillchar="-")
# Out:
# 0    ---------------Alice
# 1    -----------------Bob
# 2    ----------------Carl
# 3    ---------------David
# Name: Name, dtype: object

# %%
df["Name"].str.pad(width=20, side="right", fillchar="-")
# Out:
# 0    Alice---------------
# 1    Bob-----------------
# 2    Carl----------------
# 3    David---------------
# Name: Name, dtype: object

# %%
df["Name"].str.pad(width=20, side="both", fillchar="-")
# Out:
# 0    -------Alice--------
# 1    --------Bob---------
# 2    --------Carl--------
# 3    -------David--------
# Name: Name, dtype: object

# %% [markdown]
# Options

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

# %%
df = pd.read_csv(titanic_dataset_github_url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_rows', 3)

# %%
df
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0              1         0       3  Braund, Mr. Owen Harris  male  22.0
# ..           ...       ...     ...                      ...   ...   ...
# 890          891         0       3      Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 0        1      0  A/5 21171  7.25   NaN        S
# ..     ...    ...        ...   ...   ...      ...
# 890      0      0     370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_rows', 30)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_columns', 7)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df[['Fare', 'Age']].head()
# Out:
#       Fare   Age
# 0   7.2500  22.0
# 1  71.2833  38.0
# 2   7.9250  26.0
# 3  53.1000  35.0
# 4   8.0500  35.0

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df[['Fare', 'Age']].head()
# Out:
#    Fare   Age
# 0  7.25 22.00
# 1 71.28 38.00
# 2  7.92 26.00
# 3 53.10 35.00
# 4  8.05 35.00

# %%
pd.get_option('display.max_rows')
# Out:
# 30

# %%
with pd.option_context('display.max_rows', 3):
    print (df)
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0              1         0       3  Braund, Mr. Owen Harris  male 22.00
# ..           ...       ...     ...                      ...   ...   ...
# 890          891         0       3      Dooley, Mr. Patrick  male 32.00
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 0        1      0  A/5 21171  7.25   NaN        S
# ..     ...    ...        ...   ...   ...      ...
# 890      0      0     370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
print (df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                               Heikkinen, Miss. Laina  female 26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                             Allen, Mr. William Henry    male 35.00      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male 27.00      0
# 887                       Graham, Miss. Margaret Edith  female 19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.00      0
# 890                                Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare Cabin Embarked
# 0        0         A/5 21171  7.25   NaN        S
# 1        0          PC 17599 71.28   C85        C
# 2        0  STON/O2. 3101282  7.92   NaN        S
# 3        0            113803 53.10  C123        S
# 4        0            373450  8.05   NaN        S
# ..     ...               ...   ...   ...      ...
# 886      0            211536 13.00   NaN        S
# 887      0            112053 30.00   B42        S
# 888      2        W./C. 6607 23.45   NaN        S
# 889      0            111369 30.00  C148        C
# 890      0            370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.reset_option('display.max_rows')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                               Heikkinen, Miss. Laina  female 26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                             Allen, Mr. William Henry    male 35.00      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male 27.00      0
# 887                       Graham, Miss. Margaret Edith  female 19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.00      0
# 890                                Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare Cabin Embarked
# 0        0         A/5 21171  7.25   NaN        S
# 1        0          PC 17599 71.28   C85        C
# 2        0  STON/O2. 3101282  7.92   NaN        S
# 3        0            113803 53.10  C123        S
# 4        0            373450  8.05   NaN        S
# ..     ...               ...   ...   ...      ...
# 886      0            211536 13.00   NaN        S
# 887      0            112053 30.00   B42        S
# 888      2        W./C. 6607 23.45   NaN        S
# 889      0            111369 30.00  C148        C
# 890      0            370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.reset_option('all')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9336\2786130087.py:1: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all')
# C:\Users\HP\AppData\Local\Temp\ipykernel_9336\2786130087.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter('ignore', FutureWarning)
    pd.reset_option('all')

# %% [markdown]
# Category

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df['Sex'].dtype)
# Out:
# object

# %%
df["Sex_C"] = df["Sex"].astype("category")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Sex_C
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male

# %%
df[['Sex', 'Sex_C']].head()
# Out:
#       Sex   Sex_C
# 0    male    male
# 1  female  female
# 2  female  female
# 3  female  female
# 4    male    male

# %%
print(df['Sex'].dtype)
print(df['Sex_C'].dtype)
# Out:
# object
# category

# %%
df['Sex_C_categorical_codes'] = df['Sex_C'].cat.codes

# %%
df[['Sex', 'Sex_C', 'Sex_C_categorical_codes']].head()
# Out:
#       Sex   Sex_C  Sex_C_categorical_codes
# 0    male    male                        1
# 1  female  female                        0
# 2  female  female                        0
# 3  female  female                        0
# 4    male    male                        1

# %%
df['Sex_apply_category'] = df['Sex'].apply(lambda x : 0 if x == 'male' else 1)

# %%
df[['Sex', 'Sex_C', 'Sex_C_categorical_codes', 'Sex_apply_category']].head()
# Out:
#       Sex   Sex_C  Sex_C_categorical_codes  Sex_apply_category
# 0    male    male                        1                   0
# 1  female  female                        0                   1
# 2  female  female                        0                   1
# 3  female  female                        0                   1
# 4    male    male                        1                   0

# %%
print(df['Sex'].dtype)
print(df['Sex_C'].dtype)
print(df['Sex_C_categorical_codes'].dtype)
print(df['Sex_apply_category'].dtype)
# Out:
# object
# category
# int8
# int64

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Pclass_new_weird'] = df['Pclass'].apply(lambda x : 'abc' if x == 3 else ('tuv' if x == 2 else 'xyz'))

# %%
df[['Pclass', 'Pclass_new_weird']].head(10)
# Out:
#    Pclass Pclass_new_weird
# 0       3              abc
# 1       1              xyz
# 2       3              abc
# 3       1              xyz
# 4       3              abc
# 5       3              abc
# 6       1              xyz
# 7       3              abc
# 8       3              abc
# 9       2              tuv

# %%
print(df['Pclass'].dtype)
print(df['Pclass_new_weird'].dtype)
# Out:
# int64
# object

# %%
df['Pclass_new_weird_ordered'] = pd.Categorical(
    df['Pclass_new_weird'],
    categories=['abc','tuv', 'xyz'],
    ordered=True
)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked   Sex_C  \
# 0        0         A/5 21171   7.2500   NaN        S    male
# 1        0          PC 17599  71.2833   C85        C  female
# 2        0  STON/O2. 3101282   7.9250   NaN        S  female
# 3        0            113803  53.1000  C123        S  female
# 4        0            373450   8.0500   NaN        S    male
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    male
# 887      0            112053  30.0000   B42        S  female
# 888      2        W./C. 6607  23.4500   NaN        S  female
# 889      0            111369  30.0000  C148        C    male
# 890      0            370376   7.7500   NaN        Q    male
#
#      Sex_C_categorical_codes  Sex_apply_category Pclass_new_weird  \
# 0                          1                   0              abc
# 1                          0                   1              xyz
# 2                          0                   1              abc
# 3                          0                   1              xyz
# 4                          1                   0              abc
# ..                       ...                 ...              ...
# 886                        1                   0              tuv
# 887                        0                   1              xyz
# 888                        0                   1              abc
# 889                        1                   0              xyz
# 890                        1                   0              abc
#
#     Pclass_new_weird_ordered
# 0                        abc
# 1                        xyz
# 2                        abc
# 3                        xyz
# 4                        abc
# ..                       ...
# 886                      tuv
# 887                      xyz
# 888                      abc
# 889                      xyz
# 890                      abc
#
# [891 rows x 17 columns]

# %%
print(df['Pclass_new_weird_ordered'].dtype)
# Out:
# category

# %%
df['Pclass_new_weird_ordered'].cat.categories
# Out:
# Index(['abc', 'tuv', 'xyz'], dtype='object')

# %%
df['Pclass_new_weird_ordered'].cat.codes
# Out:
# 0      0
# 1      2
# 2      0
# 3      2
# 4      0
#       ..
# 886    1
# 887    2
# 888    0
# 889    2
# 890    0
# Length: 891, dtype: int8

# %% [markdown]
# ### Date

# %% [markdown]
# Date Basics

# %%
df = pd.DataFrame({
    'event': ['Concert', 'Conference', 'Wedding', 'Reception', 'last_day'],
    'date': ['2025-01-01', '2025-03-15', '2025-07-20', '2025-07-21', '2025-07-31']
})

# %%
df
# Out:
#         event        date
# 0     Concert  2025-01-01
# 1  Conference  2025-03-15
# 2     Wedding  2025-07-20
# 3   Reception  2025-07-21
# 4    last_day  2025-07-31

# %%
df['date_pandas'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#         event        date date_pandas
# 0     Concert  2025-01-01  2025-01-01
# 1  Conference  2025-03-15  2025-03-15
# 2     Wedding  2025-07-20  2025-07-20
# 3   Reception  2025-07-21  2025-07-21
# 4    last_day  2025-07-31  2025-07-31

# %%
print(df.dtypes[['event', 'date', 'date_pandas']])
# Out:
# event                  object
# date                   object
# date_pandas    datetime64[ns]
# dtype: object

# %%
df['date_pandas'].dt.year
# Out:
# 0    2025
# 1    2025
# 2    2025
# 3    2025
# 4    2025
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.month
# Out:
# 0    1
# 1    3
# 2    7
# 3    7
# 4    7
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.day
# Out:
# 0     1
# 1    15
# 2    20
# 3    21
# 4    31
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.weekday
# Out:
# 0    2
# 1    5
# 2    6
# 3    0
# 4    3
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.day_name()
# Out:
# 0    Wednesday
# 1     Saturday
# 2       Sunday
# 3       Monday
# 4     Thursday
# Name: date_pandas, dtype: object

# %%
df['date_pandas'].dt.is_month_end
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: date_pandas, dtype: bool

# %%
df[df['date_pandas'] > '2025-04-01']
# Out:
#        event        date date_pandas
# 2    Wedding  2025-07-20  2025-07-20
# 3  Reception  2025-07-21  2025-07-21
# 4   last_day  2025-07-31  2025-07-31

# %%
df[df['date_pandas'].between('2025-01-01', '2025-06-01')]
# Out:
#         event        date date_pandas
# 0     Concert  2025-01-01  2025-01-01
# 1  Conference  2025-03-15  2025-03-15

# %% [markdown]
# Date Range

# %%
pd.date_range(start='2024-01-01', end='2024-01-10', freq='D')
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2024-01-01', end='2024-03-10', freq='ME')
# Out:
# DatetimeIndex(['2024-01-31', '2024-02-29'], dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range(start='2024-01-01', end='2024-03-10', freq='MS')
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01'], dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# Date Arithmetic

# %%
df['next_week'] = df['date_pandas'] + pd.Timedelta(days=7)

# %%
df
# Out:
#         event        date date_pandas  next_week
# 0     Concert  2025-01-01  2025-01-01 2025-01-08
# 1  Conference  2025-03-15  2025-03-15 2025-03-22
# 2     Wedding  2025-07-20  2025-07-20 2025-07-27
# 3   Reception  2025-07-21  2025-07-21 2025-07-28
# 4    last_day  2025-07-31  2025-07-31 2025-08-07

# %%
df['days_to_event'] = df['date_pandas'] - pd.Timestamp.today()

# %%
df
# Out:
#         event        date date_pandas  next_week              days_to_event
# 0     Concert  2025-01-01  2025-01-01 2025-01-08 -166 days +05:31:47.823633
# 1  Conference  2025-03-15  2025-03-15 2025-03-22  -93 days +05:31:47.823633
# 2     Wedding  2025-07-20  2025-07-20 2025-07-27    34 days 05:31:47.823633
# 3   Reception  2025-07-21  2025-07-21 2025-07-28    35 days 05:31:47.823633
# 4    last_day  2025-07-31  2025-07-31 2025-08-07    45 days 05:31:47.823633
